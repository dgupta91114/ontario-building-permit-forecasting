# %% [markdown]
# # 01 — Data Audit and Source Verification
#
# This notebook verifies official source labels, date coverage, missingness, and one-row-per-CMA-month integrity before analysis.

# %%
from capstone.config import load_config, project_root
from capstone.download import download_all
from capstone.audit import inspect_sources

cfg = load_config()
root = project_root()
download_all(cfg, root)
inspect_sources(cfg, root)

# %% [markdown]
# Review files under `outputs/tables/source_audit/`. Update only `config/config.yaml` when an official label differs from the expected candidate labels.
