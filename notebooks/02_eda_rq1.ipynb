# %% [markdown]
# # 02 — Exploratory Analysis for RQ1
#
# RQ1 examines trend, seasonality, persistence, volatility, and structural change.

# %%
import pandas as pd
from capstone.config import load_config, project_root
from capstone.eda import run_rq1_eda

root = project_root()
cfg = load_config()
data = pd.read_csv(root / "data/processed/modeling_dataset.csv", parse_dates=["ref_date", "target_date"])
run_rq1_eda(data, cfg, root)

# %%
pd.read_csv(root / "outputs/tables/rq1_summary_by_cma.csv")

# %%
pd.read_csv(root / "outputs/tables/rq1_hac_regression.csv")
